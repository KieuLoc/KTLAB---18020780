# %%
import pandas as pd
import numpy as np

# %%
data = np.random.rand(5)
pd.Series(data)
# Out:
# 0    0.134403
# 1    0.273476
# 2    0.076072
# 3    0.865213
# 4    0.902080
# dtype: float64

# %%
pd.Series(data, index = ['Loc', 'Binh', 'Long', 'Tuan', 'Phan'])
# Out:
# Loc     0.134403
# Binh    0.273476
# Long    0.076072
# Tuan    0.865213
# Phan    0.902080
# dtype: float64

# %%
pd.DataFrame(data, columns = ["Score"], index = ['Loc', 'Long','dau', 'lo', "nam"])
# Out:
#          Score
# Loc   0.134403
# Long  0.273476
# dau   0.076072
# lo    0.865213
# nam   0.902080

# %%
solar_system = pd.read_csv('cellphoneS.csv', index_col = 0)
solar_system
# Out:
#                                                                                                  name  \
# link
# https://cellphones.com.vn/                                                                        NaN
# https://cellphones.com.vn/                                                                        NaN
# https://cellphones.com.vn/mobile/oppo.html                                                        NaN
# https://cellphones.com.vn/mobile/huawei.html                                                      NaN
# https://cellphones.com.vn/mobile/samsung.html                                                     NaN
# https://cellphones.com.vn/mobile/apple/iphone-s...                                                NaN
# https://cellphones.com.vn/mobile/xiaomi.html                                                      NaN
# https://cellphones.com.vn/mobile/asus.html                                                        NaN
# ...

# %%
solar_system.shape
# Out:
# (39, 8)

# %%
solar_system.dtypes
# Out:
# name                 object
# rating               object
# category             object
# price                object
# promotion_infor      object
# introduction         object
# short_description    object
# specification        object
# dtype: object

# %%
solar_system.describe()
# Out:
#                                   name rating          category  price  \
# count                               15     15                35      1
# unique                              15      3                10      1
# top     Apple iPhone 8 64GB Chính hãng     0   Home/ Điện thoại  price
# freq                                 1     10                16      1
#
#         promotion_infor                                       introduction  \
# count                 1                                                 39
# unique                1                                                 35
# top     promotion_infor  Cellphones.com.vn - Hệ thống bán lẻ điện thoại...
# freq                  1                                                  3
#
#         short_description                                      specification
# count                   1                                                 11
# unique                  1                                                 11
# ...

# %%
solar_system['name'].value_counts()
# Out:
# Apple iPhone 8 64GB Chính hãng                                  1
# Nokia 2.4                                                       1
# Asus Zenfone Live L1                                            1
# Apple iPhone XS 512GB Chính hãng                                1
# Tai nghe Bluetooth Samsung Galaxy Buds Live                     1
# Apple iPhone X 256GB Chính hãng                                 1
# Apple iPhone 8 256GB Chính hãng                                 1
# Samsung Galaxy A20s 64GB                                        1
#  iPhone SE 2020 128GB chính hãng VN/A                           1
# Huawei Y7 Pro 2019                                              1
# Bộ kích sóng Wifi Xiaomi Pro                                    1
# name                                                            1
# Camera IP Wifi gắn ngoài trời EZVIZ 2MP 1080P CS-CV310(C3WN)    1
# Apple iPhone 8 128GB Chính hãng                                 1
# ...

# %%
planets.iloc[5,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-83db67e0a71d> in <module>
# ----> 1 planets.iloc[5,2]
#
# NameError: name 'planets' is not defined

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# %%
df = pd.read_csv('cellphoneS.csv')

# %%
print(df)
# Out:
#                                                  link  \
# 0                          https://cellphones.com.vn/
# 1                          https://cellphones.com.vn/
# 2          https://cellphones.com.vn/mobile/oppo.html
# 3        https://cellphones.com.vn/mobile/huawei.html
# 4       https://cellphones.com.vn/mobile/samsung.html
# 5   https://cellphones.com.vn/mobile/apple/iphone-...
# 6        https://cellphones.com.vn/mobile/xiaomi.html
# 7          https://cellphones.com.vn/mobile/asus.html
# 8   https://cellphones.com.vn/mobile/apple/iphone-...
# 9   https://cellphones.com.vn/mobile/apple/iphone-...
# 10        https://cellphones.com.vn/mobile/nokia.html
# 11  https://cellphones.com.vn/mobile/hang-khac/poc...
# 12  https://cellphones.com.vn/mobile/apple/iphone-...
# 13  https://cellphones.com.vn/bo-kich-song-wifi-xi...
# 14  https://cellphones.com.vn/samsung-galaxy-buds-...
# 15  https://cellphones.com.vn/huawei-y7-pro-2019-c...
# ...
